# %% [markdown]
# # XGBoost: model experiment
#
# Global gradient-boosting model over all ~3,300 Store×Dept series

# %%
import importlib.util, subprocess, sys
from pathlib import Path

if importlib.util.find_spec("google.colab"):
    from google.colab import drive
    drive.mount("/content/drive")
    ROOT = Path("/content/drive/MyDrive/ML_FINAL_PROJECT")
else:
    ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents]
                if (p / "data" / "train.csv.zip").exists())

for pkg in ["xgboost", "optuna", "mlflow"]:
    if importlib.util.find_spec(pkg) is None:
        subprocess.run([sys.executable, "-m", "pip", "install", "-q", pkg], check=True)

sys.path.insert(0, str(ROOT))
print("ROOT =", ROOT)
# Out:
# Mounted at /content/drive
# ROOT = /content/drive/MyDrive/ML_FINAL_PROJECT

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import mlflow

from src.preprocessing import Cleaner
from src.feateng import FeatureBuilder, FEATURE_GROUPS
from src.pipeline import WalmartPipeline, LogTarget, SeasonalNaive
from src.validation import FOLDS, evaluate, split_fold, wmae
from src.experiment_utils import setup_mlflow, run_stage, log_table, PyfuncPipeline

train    = pd.read_csv(ROOT / "data/train.csv.zip")
test     = pd.read_csv(ROOT / "data/test.csv.zip")
features = pd.read_csv(ROOT / "data/features.csv.zip")
stores   = pd.read_csv(ROOT / "data/stores.csv")


DAGSHUB_REPO = "ZukaCS/ML_FINAL_PROJECT"
print("tracking:", setup_mlflow(ROOT, dagshub_repo=DAGSHUB_REPO))
print("train", train.shape, "| test", test.shape)
# Out:
# /usr/local/lib/python3.12/dist-packages/mlflow/pyfunc/utils/data_validation.py:187: UserWarning: Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
#   color_warning(
# DagsHub username (leave blank to log locally): ZukaCS
# DagsHub token: ··········
# tracking: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow
# train (421570, 5) | test (115064, 4)

# %%
_df = Cleaner(stores, features).transform(train)
_X  = FeatureBuilder(groups=["lags"]).fit(_df).transform(_df)
_s  = _df.set_index(["Store", "Dept", "Date"])["Weekly_Sales"]
_rows   = _df.sample(500, random_state=0)
_manual = _s.reindex(pd.MultiIndex.from_arrays(
    [_rows["Store"], _rows["Dept"], _rows["Date"] - pd.Timedelta(days=364)])).to_numpy()
_got = _X.loc[_rows.index, "lag_52"].to_numpy()
assert ((_manual == _got) | (np.isnan(_manual) & np.isnan(_got))).all()


_tr = train[pd.to_datetime(train["Date"]) <= pd.Timestamp(FOLDS[0]["train_end"])]
_fb = FeatureBuilder(groups=["lags"]).fit(Cleaner(stores, features).transform(_tr))
assert _fb.sales_.index.get_level_values("Date").max() <= pd.Timestamp(FOLDS[0]["train_end"])

print("sanity checks passed | lag_52 coverage on train:",
      f"{_X['lag_52'].notna().mean():.1%}")
# Out:
# sanity checks passed | lag_52 coverage on train: 62.0%

# %% [markdown]
# ## Pipeline factory

# %%
XGB_DEFAULT = dict(
    objective="reg:absoluteerror",   # L1 = the MAE inside WMAE
    n_estimators=500, learning_rate=0.1, max_depth=8,
    tree_method="hist", device="cuda", enable_categorical=True,
    random_state=42, n_jobs=-1, verbosity=0)

DEFAULT_GROUPS = ("lags", "lag_windows", "calendar", "holiday", "statics")

def make_pipeline(cfg, xgb_params=None):
    """cfg keys: clip_negatives, log_target, groups, drop_cols."""
    return WalmartPipeline(
        Cleaner(stores, features,
                clip_negatives=cfg.get("clip_negatives", True)),
        FeatureBuilder(groups=cfg.get("groups", DEFAULT_GROUPS),
                       drop_cols=cfg.get("drop_cols", ())),
        xgb.XGBRegressor(**{**XGB_DEFAULT, **(xgb_params or {})}),
        target_transform=LogTarget() if cfg.get("log_target") else None,
        holiday_weight=5.0,   #  match the 5x holiday weight in WMAE
    )

# %% [markdown]
# ## 2 · Stage: `XGBoost_Preprocessing`
#
# A/B the cleaning knobs with a default-config model:

# %%
prep_configs = {
    "clip_neg__raw":   {"clip_negatives": True,  "log_target": False},
    "keep_neg__raw":   {"clip_negatives": False, "log_target": False},
    "clip_neg__log1p": {"clip_negatives": True,  "log_target": True},
}

# fixed (not A/B'd) choices, logged on the parent run for the record
FIXED_PREP = {"markdown_impute": "zero",
              "cpi_unemp_impute": "ffill_per_store",
              "holiday_weight": 5.0}

prep_results, best_prep = run_stage(
    "XGBoost", "Preprocessing", prep_configs,
    lambda cfg: evaluate(lambda: make_pipeline(cfg), train),
    parent_log=lambda: mlflow.log_params(FIXED_PREP))

BEST_CLEAN = prep_configs[best_prep]
print("winner:", best_prep, BEST_CLEAN)
prep_results
# Out:
# [Preprocessing] clip_neg__raw: wmae_fold1=2,762, wmae_fold2=1,733, wmae_fold3=1,409, wmae_mean=1,968
# 🏃 View run clip_neg__raw at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/87c20c29833744afa953067a742f360b
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# [Preprocessing] keep_neg__raw: wmae_fold1=2,783, wmae_fold2=1,744, wmae_fold3=1,433, wmae_mean=1,987
# 🏃 View run keep_neg__raw at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/2aa13cdfe638458da2a7d7a0b217211b
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# [Preprocessing] clip_neg__log1p: wmae_fold1=2,978, wmae_fold2=1,754, wmae_fold3=1,444, wmae_mean=2,059
# 🏃 View run clip_neg__log1p at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/c78a76be25404cda8931ac92f3468620
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run XGBoost_Preprocessing at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/a5fa9eec156d44a4936575353ef02e5e
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# winner: clip_neg__raw {'clip_negatives': True, 'log_target': False}
#                   wmae_fold1   wmae_fold2   wmae_fold3    wmae_mean
# config
# clip_neg__raw    2761.813877  1732.939544  1408.820199  1967.857873
# keep_neg__raw    2782.716974  1743.851247  1433.056587  1986.541603
# clip_neg__log1p  2977.707703  1753.973976  1443.826129  2058.502603

# %% [markdown]
# ## 3 · Stage: `XGBoost_Feature_Engineering`

# %%
#  every group goes in; the selection stage decides what comes out.
ALL_GROUPS = list(FEATURE_GROUPS)

fe_results, _ = run_stage(
    "XGBoost", "Feature_Engineering",
    {"all_groups": {**BEST_CLEAN, "groups": ALL_GROUPS}},
    lambda cfg: evaluate(lambda: make_pipeline(cfg), train))

BEST_GROUPS = ALL_GROUPS
fe_results
# Out:
# [Feature_Engineering] all_groups: wmae_fold1=2,732, wmae_fold2=1,731, wmae_fold3=1,438, wmae_mean=1,967
# 🏃 View run all_groups at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/e9cdc84d7a3348fa936c808d80c4ea70
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run XGBoost_Feature_Engineering at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/008ff63359d845c9ada27b63f173dbba
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
#              wmae_fold1   wmae_fold2   wmae_fold3    wmae_mean
# config
# all_groups  2732.017344  1730.804254  1437.911842  1966.911147

# %% [markdown]
# ## 4 · Stage: `XGBoost_Feature_Selection`
#
# gain + perm

# %%
import matplotlib.pyplot as plt
from src.feateng import ID_COLS


_tr, _va = split_fold(train, FOLDS[2])
_pipe = make_pipeline({**BEST_CLEAN, "groups": BEST_GROUPS}).fit(_tr)

# gain
gain = (pd.Series(_pipe.model.feature_importances_,
                  index=_pipe.model.feature_names_in_)
        .sort_values())

# permutation
_X_va = _pipe.feature_builder.transform(
    _pipe.cleaner.transform(_va.drop(columns=["Weekly_Sales"])))
_y_va, _hol_va = _va["Weekly_Sales"].to_numpy(), _va["IsHoliday"].to_numpy()

def _wmae_on(X):
    p = np.asarray(_pipe.model.predict(X), dtype=float)
    if _pipe.target_transform is not None:
        p = _pipe.target_transform.inverse(p)
    return wmae(_y_va, p, _hol_va)

def _shuffled(X, col, rng):
    Xp = X.copy()

    Xp[col] = pd.Series(X[col].to_numpy()[rng.permutation(len(X))],
                        index=X.index, dtype=X[col].dtype)
    return Xp

_rng = np.random.default_rng(0)
_base = _wmae_on(_X_va)
perm = pd.Series(
    {c: np.mean([_wmae_on(_shuffled(_X_va, c, _rng)) for _ in range(3)]) - _base
     for c in _X_va.columns if c not in ID_COLS}).sort_values()

fig, axes = plt.subplots(1, 2, figsize=(14, 0.35 * len(gain) + 1))
gain.plot.barh(ax=axes[0]); axes[0].set_title("XGBoost gain importance (fold-3 fit)")
perm.plot.barh(ax=axes[1]); axes[1].set_title("permutation ΔWMAE (fold-3 val)")
plt.tight_layout()

low_gain  = [c for c in gain.index[gain < gain.max() * 0.001] if c not in ID_COLS]
perm_zero = list(perm.index[perm <= 0])
candidates = {
    "all_features":   [],
    "drop_low_gain":  low_gain,
    "drop_perm_zero": perm_zero,
    "drop_union":     sorted(set(low_gain) | set(perm_zero)),
}
sel_configs = {name: {**BEST_CLEAN, "groups": BEST_GROUPS, "drop_cols": drops}
               for name, drops in candidates.items()}

sel_results, best_sel = run_stage(
    "XGBoost", "Feature_Selection", sel_configs,
    lambda cfg: evaluate(lambda: make_pipeline(cfg), train),
    parent_log=lambda: mlflow.log_figure(fig, "feature_importances.png"))

FINAL_DROPS = sel_configs[best_sel]["drop_cols"]
print("winner:", best_sel, "| dropped:", FINAL_DROPS or "nothing")
sel_results
# Out:
# [Feature_Selection] all_features: wmae_fold1=2,732, wmae_fold2=1,731, wmae_fold3=1,438, wmae_mean=1,967
# 🏃 View run all_features at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/422a7d3ea9c94ae3bf8eb7db4b5eec12
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# [Feature_Selection] drop_low_gain: wmae_fold1=2,673, wmae_fold2=1,731, wmae_fold3=1,438, wmae_mean=1,947
# 🏃 View run drop_low_gain at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/55bb85587848461f964e11ac671a5049
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# [Feature_Selection] drop_perm_zero: wmae_fold1=2,556, wmae_fold2=1,733, wmae_fold3=1,417, wmae_mean=1,902
# 🏃 View run drop_perm_zero at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/93559f38ecac4cd68018bb8b3a80bbc4
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# [Feature_Selection] drop_union: wmae_fold1=2,556, wmae_fold2=1,733, wmae_fold3=1,415, wmae_mean=1,901
# 🏃 View run drop_union at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/3b2f409ac4b4458b9ce9d9061043c558
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run XGBoost_Feature_Selection at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/4f173124db0248daa6cbe31c18946b9b
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# winner: drop_union | dropped: ['IsHoliday', 'MarkDown3', 'MarkDown5', 'Month', 'Type']
#                  wmae_fold1   wmae_fold2   wmae_fold3    wmae_mean
# config
# drop_union      2555.571498  1732.624471  1414.854791  1901.016920
# drop_perm_zero  2555.571498  1732.624471  1416.644872  1901.613614
# drop_low_gain   2673.385949  1730.804254  1437.911842  1947.367348
# all_features    2732.017344  1730.804254  1437.911842  1966.911147

# %% [markdown]
# ## 5 · Stage: `XGBoost_CV` : hyperparameter tuning
#
# Optuna, TPE sampler, each trial scored on all 3 folds and logged as a nested
# run.

# %%
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

TUNED_CFG = {**BEST_CLEAN, "groups": BEST_GROUPS, "drop_cols": FINAL_DROPS}
N_TRIALS = 30

mlflow.set_experiment("XGBoost_Training")
with mlflow.start_run(run_name="XGBoost_CV"):
    mlflow.set_tag("stage", "CV")
    mlflow.log_params({"n_trials": N_TRIALS,
                       **{k: str(v) for k, v in TUNED_CFG.items()}})

    def objective(trial):
        params = dict(
            n_estimators     = trial.suggest_int("n_estimators", 300, 1200),
            learning_rate    = trial.suggest_float("learning_rate", 0.03, 0.2, log=True),
            max_depth        = trial.suggest_int("max_depth", 4, 11),
            min_child_weight = trial.suggest_float("min_child_weight", 1, 100, log=True),
            colsample_bytree = trial.suggest_float("colsample_bytree", 0.6, 1.0),
            subsample        = trial.suggest_float("subsample", 0.6, 1.0),
            reg_alpha        = trial.suggest_float("reg_alpha", 1e-3, 10, log=True),
            reg_lambda       = trial.suggest_float("reg_lambda", 1e-3, 10, log=True),
        )
        with mlflow.start_run(run_name=f"trial_{trial.number:03d}", nested=True):
            mlflow.log_params(params)
            metrics = evaluate(lambda: make_pipeline(TUNED_CFG, params), train,
                               train_metrics=True)
            mlflow.log_metrics(metrics)
        return metrics["wmae_mean"]

    study = optuna.create_study(direction="minimize",
                                sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=True)

    BEST_PARAMS = dict(study.best_params)
    mlflow.log_metric("best_wmae_mean", study.best_value)
    mlflow.log_params({f"best_{k}": v for k, v in study.best_params.items()})


    try:
        from optuna.visualization.matplotlib import (
            plot_optimization_history, plot_param_importances)
        mlflow.log_figure(plot_optimization_history(study).figure,
                          "cv_optimization_history.png")
        mlflow.log_figure(plot_param_importances(study).figure,
                          "cv_param_importances.png")
    except Exception as e:
        print("optuna plots skipped:", e)

print("best wmae_mean:", round(study.best_value, 1))
BEST_PARAMS
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 🏃 View run trial_000 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/2a2a10704b48421f919e9da0662c32d3
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_001 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/a4f3c58f94f14010be639190f9749ecb
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_002 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/3fb7c164ce074c718333c2cdff65235a
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_003 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/7d86af18e4e34187a2b999c66cffa9e0
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_004 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/b8fd42f18d0d4b799b32dcc0cac2ee74
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_005 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/c892a48fc9bd4de3b1aa0304754f39d0
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_006 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/02b8ccd39c404609ad3fdf88f1b219c8
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_007 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/6f719896e7fc4a16890a6de00bc442af
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_008 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/e221cf04871d48e69827ede199c1953b
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_009 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/36c970d640374360aaa07bad35c6a816
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_010 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/57101a50d7084377b5aa26cb73bf4635
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_011 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/dfa673aaca9f435d9f0191d1959b38ba
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_012 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/b5d3b579de0c44349c762953ee9be3ba
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_013 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/7b28a0f5056a468e952bc7ce611a2490
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_014 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/6f251a6e846442a6b7b177fe313effa4
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_015 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/cad8c364c5e6484399f9b68159eed3bc
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_016 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/62181ad96bb44f4ab2f76c2a462f784e
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_017 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/88002af0baee4c87bf547f24af4fe16d
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_018 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/6238bb1e75d84f34bef077c2a93cd26e
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_019 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/d1abc66f28b24cadaf93ebdfbab9ce3c
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_020 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/1ca2e5052eb6467dbf559c142093eaba
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_021 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/194ebea369b14e08bd0e0a0e1037d6c1
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_022 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/004bdb38c57649a3ba6b731b981bd633
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_023 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/bb8d21263a5b4c3fa99f08d5841f959a
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_024 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/8d7ebadf2e6442a48afbb11e0f4bbf3e
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_025 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/eec9bfc8d36d477c8f41d69729de3b00
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_026 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/559701a0da7244e1a93bb42b1100abca
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_027 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/0abb1436647c444d8b0373334689c02f
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_028 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/5c61661ef8ba4548aaf708c191b5ad35
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# 🏃 View run trial_029 at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/f332551cf18a41639e085ac23eadd177
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# /tmp/ipykernel_971/876013503.py:43: ExperimentalWarning: optuna.visualization.matplotlib._optimization_history.plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   mlflow.log_figure(plot_optimization_history(study).figure,
# /tmp/ipykernel_971/876013503.py:45: ExperimentalWarning: optuna.visualization.matplotlib._param_importances.plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   mlflow.log_figure(plot_param_importances(study).figure,
# 🏃 View run XGBoost_CV at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/99e96204c01245ad8a23eb1fea918cbc
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# best wmae_mean: 1792.2
# {'n_estimators': 1036,
#  'learning_rate': 0.0364793405900078,
#  'max_depth': 11,
#  'min_child_weight': 2.144908602014568,
#  'colsample_bytree': 0.800412889447534,
#  'subsample': 0.9366587051961371,
#  'reg_alpha': 0.49760883764560043,
#  'reg_lambda': 0.4841142533753913}

# %% [markdown]
# ## 6 · Stage: `XGBoost_Final`
#
# Retrain the winning config on **all** training data, log the whole
# Cleaner→FeatureBuilder→model pipeline as an MLflow pyfunc model. create submission file

# %%
mlflow.set_experiment("XGBoost_Training")
with mlflow.start_run(run_name="XGBoost_Final") as final_run:
    mlflow.set_tag("stage", "Final")

    final_pipe = make_pipeline(TUNED_CFG, BEST_PARAMS).fit(train)
    final_metrics = evaluate(lambda: make_pipeline(TUNED_CFG, BEST_PARAMS), train,
                             train_metrics=True)
    mlflow.log_params({**{k: str(v) for k, v in final_pipe.get_params().items()},
                       **{f"xgb_{k}": v for k, v in BEST_PARAMS.items()}})
    mlflow.log_metrics(final_metrics)

    preds = final_pipe.predict(test)
    assert len(preds) == len(test) and not np.isnan(preds).any()

    mlflow.pyfunc.log_model(
        name="model",
        python_model=PyfuncPipeline(final_pipe),
        code_paths=[str(ROOT / "src")],
        input_example=test.head(5),
    )

    sub = pd.DataFrame({
        "Id": test["Store"].astype(str) + "_" + test["Dept"].astype(str)
              + "_" + test["Date"].astype(str),
        "Weekly_Sales": preds,
    })
    (ROOT / "submissions").mkdir(exist_ok=True)
    sub_path = ROOT / "submissions" / "submission_xgboost.csv"
    sub.to_csv(sub_path, index=False)
    mlflow.log_artifact(str(sub_path))


print("final CV:", {k: round(v, 1) for k, v in final_metrics.items()})
print("run_id:", final_run.info.run_id)
sub.head()
# Out:
# 2026/07/08 19:22:20 WARNING mlflow.pyfunc: Passing a Python object as `python_model` causes it to be serialized using CloudPickle, it requires exercising caution as Python object serialization mechanisms may execute arbitrary code during deserialization.Consider using a file path (str or Path) instead. See https://mlflow.org/docs/latest/ml/model/models-from-code/ for details.
# 2026/07/08 19:22:20 INFO mlflow.pyfunc: Inferring model signature from input example
# /usr/local/lib/python3.12/dist-packages/mlflow/types/utils.py:440: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run XGBoost_Final at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2/runs/d57bc74779574d839e915eef7ef779c4
# 🧪 View experiment at: https://dagshub.com/ZukaCS/ML_FINAL_PROJECT.mlflow/#/experiments/2
# final CV: {'wmae_fold1': 2345.5, 'train_wmae_fold1': 881.4, 'gap_fold1': 1464.1, 'wmae_fold2': 1683.5, 'train_wmae_fold2': 941.2, 'gap_fold2': 742.3, 'wmae_fold3': 1347.7, 'train_wmae_fold3': 956.7, 'gap_fold3': 391.0, 'wmae_mean': 1792.2, 'train_wmae_mean': 926.4, 'gap_mean': 865.8}
# run_id: d57bc74779574d839e915eef7ef779c4
#                Id  Weekly_Sales
# 0  1_1_2012-11-02  37489.699219
# 1  1_1_2012-11-09  20658.767578
# 2  1_1_2012-11-16  19847.144531
# 3  1_1_2012-11-23  20566.558594
# 4  1_1_2012-11-30  26087.804688
